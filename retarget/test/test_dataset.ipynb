# %%
import numpy as np

data = np.load('/home/openhe/Workspace/program/python/smpl_retarget/assets/amass_accad_lite_output/Female1Walking_c3d/B1_-_stand_to_walk_stageii.npy', allow_pickle=True)

data = data.item()
print(data.keys())
# Out:
# dict_keys(['file_name', 'fps', 'time_length', 'num_frames', 'root_pos', 'root_rot', 'dof_pos', 'root_vel', 'root_ang_vel', 'dof_vel', 'keypoint_trans'])

# %%
for key in data.keys():
    if key not in ['file_name', 'fps', 'time_length','num_frames']:
        print(f"{key} => {data[key].shape}")
# Out:
# root_pos => (374, 3)
# root_rot => (374, 4)
# dof_pos => (374, 27)
# root_vel => (374, 3)
# root_ang_vel => (374, 3)
# dof_vel => (374, 27)
# keypoint_trans => (374, 12, 3)

# %%
data['time_length']*data['fps'], data['num_frames']
# Out:
# (373.5, 374)

# %%
import numpy as np

data = np.load('../retarget_input/B1_-_stand_to_walk_stageii.npz', allow_pickle=True)

for key in data:
    print(key)
# Out:
# gender
# surface_model_type
# mocap_frame_rate
# mocap_time_length
# markers_latent
# latent_labels
# markers_latent_vids
# trans
# poses
# betas
# num_betas
# root_orient
# pose_body
# pose_hand
# pose_jaw
# pose_eye
# markers
# labels
# markers_obs
# labels_obs
# markers_sim
# marker_meta
# num_markers

# %%
print(data['gender'])
print(data['surface_model_type'])
print(data['mocap_frame_rate'])
print(data['mocap_time_length'])
print(data['markers_latent'].shape)
print(data['trans'].shape)
print(data['poses'].shape)
print(data['betas'].shape)
print(data['num_betas'])
print(data['root_orient'].shape)
# Out:
# female
# smplx
# 120.0
# 6.225
# (41, 3)
# (747, 3)
# (747, 165)
# (16,)
# 16
# (747, 3)

# %%
print(data['pose_body'].shape)
print(data['pose_hand'].shape)
print(data['pose_jaw'].shape)
print(data['pose_eye'].shape)
print(data['poses'].shape)
# Out:
# (747, 63)
# (747, 90)
# (747, 3)
# (747, 6)
# (747, 165)

# %%
data['labels_obs']
# Out:
# array([list(['C7', 'CLAV', 'LBHD', 'LBWT', 'LELB', 'LFHD', 'LFIN', 'LFRM', 'LFWT', 'LHEE', 'LIWR', 'LKNE', 'LMT5', 'LOWR', 'LSHN', 'LSHO', 'LTHI', 'LTOE', 'LUPA', 'RANK', 'RBAK', 'RBHD', 'RBWT', 'RELB', 'RFHD', 'RFIN', 'RFRM', 'RFWT', 'RHEE', 'RIWR', 'RKNE', 'RMT5', 'ROWR', 'RSHN', 'RSHO', 'RTHI', 'RTOE', 'RUPA', 'T10']),
#        list(['C7', 'CLAV', 'LBHD', 'LBWT', 'LELB', 'LFHD', 'LFIN', 'LFRM', 'LFWT', 'LHEE', 'LIWR', 'LKNE', 'LMT5', 'LOWR', 'LSHN', 'LSHO', 'LTHI', 'LTOE', 'LUPA', 'RANK', 'RBAK', 'RBHD', 'RBWT', 'RELB', 'RFHD', 'RFIN', 'RFRM', 'RFWT', 'RHEE', 'RIWR', 'RKNE', 'RMT5', 'ROWR', 'RSHN', 'RSHO', 'RTHI', 'RTOE', 'RUPA', 'T10']),
#        list(['C7', 'CLAV', 'LBHD', 'LBWT', 'LELB', 'LFHD', 'LFIN', 'LFRM', 'LFWT', 'LHEE', 'LIWR', 'LKNE', 'LMT5', 'LOWR', 'LSHN', 'LSHO', 'LTHI', 'LTOE', 'LUPA', 'RANK', 'RBAK', 'RBHD', 'RBWT', 'RELB', 'RFHD', 'RFIN', 'RFRM', 'RFWT', 'RHEE', 'RIWR', 'RKNE', 'RMT5', 'ROWR', 'RSHN', 'RSHO', 'RTHI', 'RTOE', 'RUPA', 'T10']),
# ...
